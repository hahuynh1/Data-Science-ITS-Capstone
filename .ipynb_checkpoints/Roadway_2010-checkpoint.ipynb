# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load the dataset

# %%
tens = pd.read_csv('ROADWAY_PHILADELPHIA_2010.csv')

# %% [markdown]
# Check the columns, if useful or not

# %%
tens.head()
# Out:
#           CRN  ACCESS_CTRL  ADJ_RDWY_SEQ  LANE_COUNT  OFFSET  RDWY_COUNTY  \
# 0  2010074986          NaN             3         2.0     NaN           67
# 1  2010028332          NaN             5         2.0     NaN           67
# 2  2010099744          NaN             4         2.0     0.0           67
# 3  2010059552          1.0             6         2.0   425.0           67
# 4  2010064669          NaN             3         2.0     NaN           67
#
#   RDWY_ORIENT  RDWY_SEQ_NUM  ROAD_OWNER   ROUTE  SEGMENT  SPEED_LIMIT  \
# 0           E             4           4     NaN      NaN         25.0
# 1           E             5           4     NaN      NaN         25.0
# 2           S             4           2  3015.0     53.0         25.0
# 3           E             6           2  8014.0    500.0          NaN
# 4           N             4           4     NaN      NaN          NaN
#
#       STREET_NAME
# 0        NEDRO AV
# 1       MASTER ST
# 2  COBBS CREEK PY
# 3       RAMP A RD
# ...

# %% [markdown]
# Get rid of unwanted columns

# %%
delcoltens = tens.drop(columns=['ACCESS_CTRL', 'OFFSET', 'RDWY_COUNTY', 'RDWY_ORIENT', 'ROAD_OWNER'])

# %% [markdown]
# Check if the columns were deleted

# %%
delcoltens.head()
# Out:
#           CRN  ADJ_RDWY_SEQ  LANE_COUNT  RDWY_SEQ_NUM   ROUTE  SEGMENT  \
# 0  2010074986             3         2.0             4     NaN      NaN
# 1  2010028332             5         2.0             5     NaN      NaN
# 2  2010099744             4         2.0             4  3015.0     53.0
# 3  2010059552             6         2.0             6  8014.0    500.0
# 4  2010064669             3         2.0             4     NaN      NaN
#
#    SPEED_LIMIT     STREET_NAME
# 0         25.0        NEDRO AV
# 1         25.0       MASTER ST
# 2         25.0  COBBS CREEK PY
# 3          NaN       RAMP A RD
# 4          NaN      TWELFTH ST
